# %%
# import library
import pickle
import pandas as pd
import numpy as np

import xgboost as xgb
import lightgbm as lgb

from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from keras import models
from keras import layers
from keras.layers.advanced_activations import LeakyReLU
from keras.utils import np_utils
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Dense, GaussianNoise, GaussianDropout
from keras.models import Sequential, Model
from keras.regularizers import l2, l1
from keras.optimizers import Adam, SGD, Nadam
from keras.callbacks import LearningRateScheduler
from keras.metrics import categorical_accuracy
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
from keras.wrappers.scikit_learn import KerasClassifier
from  keras.regularizers import l1, l2
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects

import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options=tf.GPUOptions(
        visible_device_list="1", 
        allow_growth=True,
#         per_process_gpu_memory_fraction=0.5
    )
)
set_session(tf.Session(config=config))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# read data
df = pd.read_csv('../data/feature_selection_positive.csv')


# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# transform  for keras's target label
y_train_for_keras = np_utils.to_categorical(y_train)
y_test_for_keras = np_utils.to_categorical(y_test)

# %%
# define and fit
clf = rf()
clf = clf.fit(X_train, y_train)

# result append to list
t = []
t.append(round(clf.score(X_test, y_test)*100, 2))
pickle.dump(clf, open('../model/rf_pos_fs.sav', 'wb'))

# %%
# define and fit
gbm = lgb.LGBMClassifier(
    objective='multiclass',
    device = 'gpu'
)

gbm.fit(
    X_train, 
    y_train,
    eval_set=[(X_test, y_test)],
    early_stopping_rounds=5
)

pickle.dump(gbm, open('../model/lgbm_pos_fs.sav', 'wb'))
# result append to list
t.append(round(gbm.score(X_test, y_test)*100, 2))
# Out:
# [1]	valid_0's multi_logloss: 1.29182
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's multi_logloss: 1.21089
# [3]	valid_0's multi_logloss: 1.14382
# [4]	valid_0's multi_logloss: 1.08417
# [5]	valid_0's multi_logloss: 1.03056
# [6]	valid_0's multi_logloss: 0.985742
# [7]	valid_0's multi_logloss: 0.941113
# [8]	valid_0's multi_logloss: 0.904691
# [9]	valid_0's multi_logloss: 0.870199
# [10]	valid_0's multi_logloss: 0.840181
# [11]	valid_0's multi_logloss: 0.811884
# [12]	valid_0's multi_logloss: 0.790346
# [13]	valid_0's multi_logloss: 0.767064
# [14]	valid_0's multi_logloss: 0.745129
# [15]	valid_0's multi_logloss: 0.725548
# [16]	valid_0's multi_logloss: 0.708124
# [17]	valid_0's multi_logloss: 0.689667
# [18]	valid_0's multi_logloss: 0.673591
# [19]	valid_0's multi_logloss: 0.657719
# [20]	valid_0's multi_logloss: 0.642468
# [21]	valid_0's multi_logloss: 0.630587
# [22]	valid_0's multi_logloss: 0.618657
# [23]	valid_0's multi_logloss: 0.6075
# [24]	valid_0's multi_logloss: 0.598352
# [25]	valid_0's multi_logloss: 0.588099
# [26]	valid_0's multi_logloss: 0.579953
# [27]	valid_0's multi_logloss: 0.570411
# [28]	valid_0's multi_logloss: 0.561208
# [29]	valid_0's multi_logloss: 0.553208
# [30]	valid_0's multi_logloss: 0.544201
# [31]	valid_0's multi_logloss: 0.540103
# [32]	valid_0's multi_logloss: 0.532857
# [33]	valid_0's multi_logloss: 0.526945
# [34]	valid_0's multi_logloss: 0.520935
# [35]	valid_0's multi_logloss: 0.518574
# [36]	valid_0's multi_logloss: 0.512898
# [37]	valid_0's multi_logloss: 0.509127
# [38]	valid_0's multi_logloss: 0.506726
# [39]	valid_0's multi_logloss: 0.501514
# [40]	valid_0's multi_logloss: 0.496471
# [41]	valid_0's multi_logloss: 0.491807
# [42]	valid_0's multi_logloss: 0.488786
# [43]	valid_0's multi_logloss: 0.486133
# [44]	valid_0's multi_logloss: 0.481587
# [45]	valid_0's multi_logloss: 0.4791
# [46]	valid_0's multi_logloss: 0.473296
# [47]	valid_0's multi_logloss: 0.470258
# [48]	valid_0's multi_logloss: 0.466695
# [49]	valid_0's multi_logloss: 0.464183
# [50]	valid_0's multi_logloss: 0.462237
# [51]	valid_0's multi_logloss: 0.458458
# [52]	valid_0's multi_logloss: 0.456505
# [53]	valid_0's multi_logloss: 0.454772
# [54]	valid_0's multi_logloss: 0.453193
# [55]	valid_0's multi_logloss: 0.451146
# [56]	valid_0's multi_logloss: 0.448771
# [57]	valid_0's multi_logloss: 0.447916
# [58]	valid_0's multi_logloss: 0.44818
# [59]	valid_0's multi_logloss: 0.446262
# [60]	valid_0's multi_logloss: 0.446638
# [61]	valid_0's multi_logloss: 0.4472
# [62]	valid_0's multi_logloss: 0.446037
# [63]	valid_0's multi_logloss: 0.444476
# [64]	valid_0's multi_logloss: 0.443099
# [65]	valid_0's multi_logloss: 0.443044
# [66]	valid_0's multi_logloss: 0.444093
# [67]	valid_0's multi_logloss: 0.443968
# [68]	valid_0's multi_logloss: 0.44174
# [69]	valid_0's multi_logloss: 0.438419
# [70]	valid_0's multi_logloss: 0.439017
# [71]	valid_0's multi_logloss: 0.438065
# [72]	valid_0's multi_logloss: 0.439394
# [73]	valid_0's multi_logloss: 0.439386
# [74]	valid_0's multi_logloss: 0.439075
# [75]	valid_0's multi_logloss: 0.438704
# [76]	valid_0's multi_logloss: 0.438525
# Early stopping, best iteration is:
# [71]	valid_0's multi_logloss: 0.438065
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# set parameters
params = {}
params['device'] = 'gpu'
params['gpu_id'] = 1
params['updater'] = 'grow_gpu_hist'

# %%
# define and fit
model = xgb.XGBClassifier(**params)
model.fit(X_train, y_train)

# result append to list
pickle.dump(model, open('../model/xgb_pos_fs.sav', 'wb'))
t.append(round(model.score(X_test, y_test)*100, 2))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
tf.set_random_seed(42)

# make keras model

inputs = Input(shape=(X_train.shape[1],))

x = Dense(512, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(len(df['Subclass'].value_counts()), activation='softmax')(x)
model = Model(inputs=inputs, outputs=predictions)

# compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['accuracy']
)

# fit
epochs = 100
batch_size = 1000
es = EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(
    X_train,
    y_train_for_keras,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=
# Epoch 96/100
# 1340/1340 [==============================] - 0s 95us/step - loss: 0.2663 - acc: 0.9075 - val_loss: 0.8756 - val_acc: 0.6369
# Epoch 97/100
# 1340/1340 [==============================] - 0s 83us/step - loss: 0.2525 - acc: 0.9045 - val_loss: 0.8940 - val_acc: 0.6250
# Epoch 98/100
# 1340/1340 [==============================] - 0s 92us/step - loss: 0.2420 - acc: 0.9149 - val_loss: 0.9030 - val_acc: 0.6369
# Epoch 99/100
# 1340/1340 [==============================] - 0s 98us/step - loss: 0.2792 - acc: 0.9067 - val_loss: 0.8980 - val_acc: 0.6488
# Epoch 100/100
# 1340/1340 [==============================] - 0s 100us/step - loss: 0.2659 - acc: 0.8978 - val_loss: 0.8825 - val_acc: 0.6637

# %%
f = []
f.append(t)

# %%
f
# Out:
# [[72.32, 84.52, 83.04, 66.37]]

# %%
#read data
df = pd.read_csv('../data/feature_selection_negative.csv')

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# transform  for keras's target label
y_train_for_keras = np_utils.to_categorical(y_train)
y_test_for_keras = np_utils.to_categorical(y_test)

# %%
# define and fit 
clf = rf()
clf = clf.fit(X_train, y_train)

# result append to list
t = []
t.append(round(clf.score(X_test, y_test)*100, 2))
print(round(clf.score(X_test, y_test)*100, 2))
pickle.dump(clf, open('../model/rf_ng_fs.sav', 'wb'))
# Out:
# 72.34

# %%
# define and fit
gbm = lgb.LGBMClassifier(
    objective='multiclass',
    device = 'gpu'
)

gbm.fit(
    X_train, 
    y_train,
    eval_set=[(X_test, y_test)],
    early_stopping_rounds=5
)

# pickle.dump(gbm, open('../model/lgbm_ng_fs.sav', 'wb'))
# result append to list
# t.append(
round(gbm.score(X_test, y_test)*100, 2)
# )
# Out:
# [1]	valid_0's multi_logloss: 1.30732
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's multi_logloss: 1.24253
# [3]	valid_0's multi_logloss: 1.17804
# [4]	valid_0's multi_logloss: 1.13119
# [5]	valid_0's multi_logloss: 1.0872
# [6]	valid_0's multi_logloss: 1.04603
# [7]	valid_0's multi_logloss: 1.00813
# [8]	valid_0's multi_logloss: 0.973739
# [9]	valid_0's multi_logloss: 0.94484
# [10]	valid_0's multi_logloss: 0.914159
# [11]	valid_0's multi_logloss: 0.890914
# [12]	valid_0's multi_logloss: 0.867582
# [13]	valid_0's multi_logloss: 0.849518
# [14]	valid_0's multi_logloss: 0.831571
# [15]	valid_0's multi_logloss: 0.820261
# [16]	valid_0's multi_logloss: 0.803279
# [17]	valid_0's multi_logloss: 0.791579
# [18]	valid_0's multi_logloss: 0.777359
# [19]	valid_0's multi_logloss: 0.769047
# [20]	valid_0's multi_logloss: 0.75922
# [21]	valid_0's multi_logloss: 0.751214
# [22]	valid_0's multi_logloss: 0.744432
# [23]	valid_0's multi_logloss: 0.735026
# [24]	valid_0's multi_logloss: 0.727465
# [25]	valid_0's multi_logloss: 0.721586
# [26]	valid_0's multi_logloss: 0.715456
# [27]	valid_0's multi_logloss: 0.710521
# [28]	valid_0's multi_logloss: 0.706789
# [29]	valid_0's multi_logloss: 0.701095
# [30]	valid_0's multi_logloss: 0.695703
# [31]	valid_0's multi_logloss: 0.690639
# [32]	valid_0's multi_logloss: 0.685989
# [33]	valid_0's multi_logloss: 0.678304
# [34]	valid_0's multi_logloss: 0.672691
# [35]	valid_0's multi_logloss: 0.671452
# [36]	valid_0's multi_logloss: 0.670582
# [37]	valid_0's multi_logloss: 0.663714
# [38]	valid_0's multi_logloss: 0.662432
# [39]	valid_0's multi_logloss: 0.661597
# [40]	valid_0's multi_logloss: 0.661375
# [41]	valid_0's multi_logloss: 0.658054
# [42]	valid_0's multi_logloss: 0.653902
# [43]	valid_0's multi_logloss: 0.65112
# [44]	valid_0's multi_logloss: 0.645407
# [45]	valid_0's multi_logloss: 0.645483
# [46]	valid_0's multi_logloss: 0.64588
# [47]	valid_0's multi_logloss: 0.646032
# [48]	valid_0's multi_logloss: 0.645287
# [49]	valid_0's multi_logloss: 0.643535
# [50]	valid_0's multi_logloss: 0.641042
# [51]	valid_0's multi_logloss: 0.637002
# [52]	valid_0's multi_logloss: 0.638699
# [53]	valid_0's multi_logloss: 0.641313
# [54]	valid_0's multi_logloss: 0.638999
# [55]	valid_0's multi_logloss: 0.636674
# [56]	valid_0's multi_logloss: 0.63702
# [57]	valid_0's multi_logloss: 0.639871
# [58]	valid_0's multi_logloss: 0.638538
# [59]	valid_0's multi_logloss: 0.639735
# [60]	valid_0's multi_logloss: 0.642856
# Early stopping, best iteration is:
# [55]	valid_0's multi_logloss: 0.636674
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 74.47

# %%
# setting parameters
params = {}
params['device'] = 'gpu'
params['gpu_id'] = 1
params['updater'] = 'grow_gpu_hist'

# %%
# define and fit 
model = xgb.XGBClassifier(**params)
model.fit(X_train, y_train)

# result append to list
t.append(round(model.score(X_test, y_test)*100, 2))
pickle.dump(model, open('../model/xgb_ng_fs.sav', 'wb'))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
tf.set_random_seed(42)

# make keras model

inputs = Input(shape=(X_train.shape[1],))

x = Dense(512, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(len(df['Subclass'].value_counts()), activation='softmax')(x)
model = Model(inputs=inputs, outputs=predictions)

# compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['accuracy']
)

# fit
epochs = 100
batch_size = 1000
es = EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(
    X_train,
    y_train_for_keras,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_test, y_test_for_keras),
    verbose=1,
    callbacks=[
        es,
#         lr_decay
    ]
)

model.save('../model/Keras_ng_fs.h5')
t.append(round(model.evaluate(X_test, y_test_for_keras, verbose=0)[1]*100, 2))
# Out:
# Train on 373 samples, validate on 94 samples
# Epoch 1/100
# 373/373 [==============================] - 4s 9ms/step - loss: 2.2452 - acc: 0.2895 - val_loss: 1.3235 - val_acc: 0.3617
# Epoch 2/100
# 373/373 [==============================] - 0s 95us/step - loss: 1.8801 - acc: 0.2922 - val_loss: 1.2898 - val_acc: 0.4681
# Epoch 3/100
# 373/373 [==============================] - 0s 89us/step - loss: 1.8880 - acc: 0.3271 - val_loss: 1.3738 - val_acc: 0.4787
# Epoch 4/100
# 373/373 [==============================] - 0s 91us/step - loss: 1.7928 - acc: 0.3244 - val_loss: 1.4410 - val_acc: 0.4894
# Epoch 5/100
