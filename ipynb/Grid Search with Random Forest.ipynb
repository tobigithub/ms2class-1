# %%
# import some library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# read data
df = pd.concat([
    pd.read_csv('../data/feature_selection_positive.csv', index_col=0),
    pd.read_csv('../data/decomp_pos.csv', index_col=0).drop('Subclass', axis=1)
], axis=1)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=2
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   6.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   7.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   7.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   7.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   7.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   7.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   7.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   8.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   8.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   8.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   8.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   9.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   8.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   6.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   8.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   8.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   7.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   8.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   8.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   8.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   8.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   9.0s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   8.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   8.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   8.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   6.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   8.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   8.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   8.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   8.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   8.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   8.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   6.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   7.8s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   8.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   7.8s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   38.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   7.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   8.1s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   7.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   7.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   8.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   7.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   7.7s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   8.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# ...
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  33.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  33.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  34.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  32.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  34.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  33.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  35.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  34.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  34.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  40.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  40.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  42.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  40.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  40.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  39.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  41.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  38.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  40.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  39.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  39.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  39.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  39.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  39.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  37.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  40.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  37.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  40.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  40.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  38.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  38.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  38.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  38.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  39.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  37.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  37.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  36.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  38.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  35.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  36.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  36.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  38.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  36.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  37.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  37.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  39.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  31.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  28.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  31.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  31.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  28.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  29.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  30.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  29.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  29.9s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:  9.1min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [1, 5, 10, None], 'max_features': [1, 'auto', None], 'min_samples_leaf': [1, 2, 4], 'min_samples_split': [5, 6, 7, 9, 11], 'criterion': ['gini'], 'n_estimators': [100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
f = grid_search.best_estimator_

pickle.dump(f, open('../model/rf_gs_pos.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
# Out:
# Train score: 1.0
# Test score: 0.8095238095238095

# %%
# read data
df = pd.concat([
    pd.read_csv('../data/feature_selection_negative.csv', index_col=0),
    pd.read_csv('../data/decomp_neg.csv', index_col=0).drop('Subclass', axis=1)
], axis=1)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=1
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:   51.6s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [1, 5, 10, None], 'max_features': [1, 'auto', None], 'min_samples_leaf': [1, 2, 4], 'min_samples_split': [5, 6, 7, 9, 11], 'criterion': ['gini'], 'n_estimators': [100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
f = grid_search.best_estimator_

pickle.dump(f, open('../model/rf_gs_neg.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
# Out:
# Train score: 0.9892761394101877
# Test score: 0.7659574468085106

# %%
# read data
df = pd.read_csv('../data/feature_selection_positive.csv', index_col=0)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=2
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   3.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   3.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   3.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   19.0s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   3.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   3.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.1s
# ...
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   0.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  25.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  25.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  24.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  26.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  26.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  25.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  26.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  26.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  26.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  30.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  31.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=  31.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  30.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  30.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  29.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  31.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=  31.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  30.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  30.3s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=  30.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=  31.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  30.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  30.7s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=  30.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  28.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  28.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  30.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  29.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  29.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=  30.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  29.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=  30.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=  29.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  28.8s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  29.5s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=  29.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  28.9s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  26.6s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  26.4s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  27.2s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=  27.1s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  27.0s
# [CV] bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  28.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=  27.2s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=  29.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  25.0s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  21.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  22.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  22.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  21.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  23.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  22.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  22.9s
# [CV]  bootstrap=True, criterion=gini, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  23.1s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:  5.3min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [1, 5, 10, None], 'max_features': [1, 'auto', None], 'min_samples_leaf': [1, 2, 4], 'min_samples_split': [5, 6, 7, 9, 11], 'criterion': ['gini'], 'n_estimators': [100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
f = grid_search.best_estimator_

pickle.dump(f, open('../model_gs/rf_gs_pos_fs.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
# Out:
# Train score: 0.9977611940298508
# Test score: 0.7916666666666666

# %%
# read data
df = pd.read_csv('../data/feature_selection_negative.csv', index_col=0)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [1000]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=1
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:  6.2min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [1, 5, 10, None], 'max_features': [1, 'auto', None], 'min_samples_leaf': [1, 2, 4], 'min_samples_split': [5, 6, 7, 9, 11], 'criterion': ['gini'], 'n_estimators': [1000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
f = grid_search.best_estimator_

# pickle.dump(f, open('../model/rf_gs_neg.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
# Out:
# Train score: 1.0
# Test score: 0.7446808510638298

# %%
# read data
with open('../data/HCD35_pos.pickle', mode='rb') as fp:
    df = pickle.load(fp)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [10]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=1
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:  6.2min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [1, 5, 10, None], 'max_features': [1, 'auto', None], 'min_samples_leaf': [1, 2, 4], 'min_samples_split': [5, 6, 7, 9, 11], 'criterion': ['gini'], 'n_estimators': [10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
f = grid_search.best_estimator_

# pickle.dump(f, open('../model/rf_gs_neg.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
# Out:
# Train score: 0.9537313432835821
# Test score: 0.7857142857142857

# %%
# read data
with open('../data/HCD45_pos.pickle', mode='rb') as fp:
    df = pickle.load(fp)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=2
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   4.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   5.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   4.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   3.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   4.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   4.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   5.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   4.1s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  2.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   4.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   4.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   2.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   4.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   2.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   2.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   5.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   4.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   4.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   5.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   4.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   4.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   4.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   4.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   5.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   5.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   5.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   4.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   3.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   4.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   5.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   3.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   5.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   2.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   4.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   5.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   4.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   5.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   1.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   4.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   5.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   5.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   5.3s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   5.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   3.9s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   4.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   5.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   5.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   2.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   5.1s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   4.8s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   5.5s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   4.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.2s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.7s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   2.1s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   5.0s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   2.6s
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total= 1.9min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total= 2.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total= 2.3min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total= 2.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total= 2.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total= 2.4min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total= 2.4min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total= 2.4min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total= 2.4min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total= 2.4min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total= 2.5min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total= 2.7min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total= 3.0min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total= 3.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total= 3.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total= 3.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total= 3.0min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total= 3.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total= 3.3min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total= 3.3min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total= 3.3min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total= 3.2min
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total= 2.9min
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total= 3.1min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total= 3.2min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total= 3.0min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total= 2.7min
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total= 2.5min
# [CV] bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total= 2.3min
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.7s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total= 2.0min
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.6s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total= 1.1min
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  45.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 19.6min
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  38.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  31.0s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  22.8s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  14.7s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  13.1s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  12.6s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=1, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  12.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.6s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.6s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   3.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   4.2s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.3s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   3.4s
# [CV] bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=1, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=   4.2s
# ...
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=9, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   2.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   1.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   2.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=  59.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total= 1.0min
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   2.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, total=   1.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   1.5s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   1.7s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=100, total=   1.7s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=  59.4s
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   1.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  57.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   1.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total= 1.0min
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  57.8s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=11, n_estimators=100, total=   1.3s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed: 25.8min
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total= 1.0min
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   1.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  58.5s
# [CV]  bootstrap=True, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total= 1.0min
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100, total=   1.1s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   1.1s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   1.1s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   0.9s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=100, total=   1.0s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   1.3s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   4.4s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=9, n_estimators=100, total=   6.7s
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  10.5s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  10.3s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=11, n_estimators=100, total=  11.7s
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=7, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# [CV] bootstrap=True, criterion=gini, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d5717677ac0f> in <module>()
#      17 )
#      18
# ---> 19 grid_search.fit(X_train, y_train)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
f = grid_search.best_estimator_

print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))

# %%
# read data
with open('../data/HCD65_pos.pickle', mode='rb') as fp:
    df = pickle.load(fp)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=1
)

grid_search.fit(X_train, y_train)

# %%
f = grid_search.best_estimator_

# pickle.dump(f, open('../model/rf_gs_neg.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))

# %%
# read data
with open('../data/HCD65_pos.pickle', mode='rb') as fp:
    df = pickle.load(fp)

# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [1, 5, 10, None],
    'max_features': [1, 'auto', None],
    'min_samples_leaf': [1, 2, 4,],
    'min_samples_split': [5, 6, 7, 9, 11],
    'criterion' :['gini'],
    'n_estimators': [100]
}

grid_search = GridSearchCV(
    estimator = rf(), 
    param_grid = param_grid, 
    cv = 3, 
    n_jobs = -1, 
    verbose=1
)

grid_search.fit(X_train, y_train)

# %%
f = grid_search.best_estimator_

# pickle.dump(f, open('../model/rf_gs_neg.sav', 'wb'))
print('Train score: {}'.format(f.score(X_train, y_train)))
print('Test score: {}'.format(f.score(X_test, y_test)))
