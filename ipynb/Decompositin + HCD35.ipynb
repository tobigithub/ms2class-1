# %%
# import library
import pickle
import pandas as pd
import numpy as np

import xgboost as xgb
import lightgbm as lgb

from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from keras import models
from keras import layers
from keras.layers.advanced_activations import LeakyReLU
from keras.utils import np_utils
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Dense, GaussianNoise, GaussianDropout
from keras.models import Sequential, Model
from keras.regularizers import l2, l1
from keras.optimizers import Adam, SGD, Nadam
from keras.callbacks import LearningRateScheduler
from keras.metrics import categorical_accuracy
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
from keras.wrappers.scikit_learn import KerasClassifier
from  keras.regularizers import l1, l2
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects

import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options=tf.GPUOptions(
        visible_device_list="1", 
        allow_growth=True,
#         per_process_gpu_memory_fraction=0.5
    )
)
set_session(tf.Session(config=config))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# read data
with open('../data/HCD35_pos.pickle', mode='rb') as fp:
    df_3 = pickle.load(fp)
    
df = pd.concat([
    df_3,
    pd.read_csv('../data/decomp_pos.csv').drop('Subclass', axis=1)
], axis=1)

# %%
# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# transform  for keras's target label
y_train_for_keras = np_utils.to_categorical(y_train)
y_test_for_keras = np_utils.to_categorical(y_test)

# %%
# define and fit
clf = rf()
clf = clf.fit(X_train, y_train)

# result append to list
t = []
t.append(round(clf.score(X_test, y_test)*100, 2))
# pickle.dump(clf, open('../model/rf_pos_fs.sav', 'wb'))

# %%
# define and fit
gbm = lgb.LGBMClassifier(
    objective='multiclass',
    device = 'gpu'
)

gbm.fit(
    X_train, 
    y_train,
    eval_set=[(X_test, y_test)],
    early_stopping_rounds=5
)

# pickle.dump(gbm, open('../model/lgbm_pos_fs.sav', 'wb'))
# result append to list
t.append(round(gbm.score(X_test, y_test)*100, 2))
# Out:
# [1]	valid_0's multi_logloss: 1.29038
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's multi_logloss: 1.2103
# [3]	valid_0's multi_logloss: 1.14562
# [4]	valid_0's multi_logloss: 1.08966
# [5]	valid_0's multi_logloss: 1.04147
# [6]	valid_0's multi_logloss: 0.998684
# [7]	valid_0's multi_logloss: 0.960006
# [8]	valid_0's multi_logloss: 0.926932
# [9]	valid_0's multi_logloss: 0.894773
# [10]	valid_0's multi_logloss: 0.863415
# [11]	valid_0's multi_logloss: 0.833717
# [12]	valid_0's multi_logloss: 0.81067
# [13]	valid_0's multi_logloss: 0.784644
# [14]	valid_0's multi_logloss: 0.767108
# [15]	valid_0's multi_logloss: 0.742354
# [16]	valid_0's multi_logloss: 0.723768
# [17]	valid_0's multi_logloss: 0.707918
# [18]	valid_0's multi_logloss: 0.690655
# [19]	valid_0's multi_logloss: 0.673968
# [20]	valid_0's multi_logloss: 0.659024
# [21]	valid_0's multi_logloss: 0.645974
# [22]	valid_0's multi_logloss: 0.632905
# [23]	valid_0's multi_logloss: 0.6219
# [24]	valid_0's multi_logloss: 0.611525
# [25]	valid_0's multi_logloss: 0.600084
# [26]	valid_0's multi_logloss: 0.590232
# [27]	valid_0's multi_logloss: 0.580757
# [28]	valid_0's multi_logloss: 0.569428
# [29]	valid_0's multi_logloss: 0.560227
# [30]	valid_0's multi_logloss: 0.550545
# [31]	valid_0's multi_logloss: 0.544691
# [32]	valid_0's multi_logloss: 0.536214
# [33]	valid_0's multi_logloss: 0.529858
# [34]	valid_0's multi_logloss: 0.524536
# [35]	valid_0's multi_logloss: 0.517663
# [36]	valid_0's multi_logloss: 0.511835
# [37]	valid_0's multi_logloss: 0.505962
# [38]	valid_0's multi_logloss: 0.499723
# [39]	valid_0's multi_logloss: 0.496933
# [40]	valid_0's multi_logloss: 0.49051
# [41]	valid_0's multi_logloss: 0.486992
# [42]	valid_0's multi_logloss: 0.482906
# [43]	valid_0's multi_logloss: 0.479541
# [44]	valid_0's multi_logloss: 0.47689
# [45]	valid_0's multi_logloss: 0.473086
# [46]	valid_0's multi_logloss: 0.470677
# [47]	valid_0's multi_logloss: 0.467565
# [48]	valid_0's multi_logloss: 0.464847
# [49]	valid_0's multi_logloss: 0.463385
# [50]	valid_0's multi_logloss: 0.458954
# [51]	valid_0's multi_logloss: 0.458212
# [52]	valid_0's multi_logloss: 0.455976
# [53]	valid_0's multi_logloss: 0.45465
# [54]	valid_0's multi_logloss: 0.452506
# [55]	valid_0's multi_logloss: 0.449889
# [56]	valid_0's multi_logloss: 0.448141
# [57]	valid_0's multi_logloss: 0.444859
# [58]	valid_0's multi_logloss: 0.444474
# [59]	valid_0's multi_logloss: 0.441914
# [60]	valid_0's multi_logloss: 0.440957
# [61]	valid_0's multi_logloss: 0.440521
# [62]	valid_0's multi_logloss: 0.438186
# [63]	valid_0's multi_logloss: 0.436954
# [64]	valid_0's multi_logloss: 0.436258
# [65]	valid_0's multi_logloss: 0.436106
# [66]	valid_0's multi_logloss: 0.435578
# [67]	valid_0's multi_logloss: 0.432373
# [68]	valid_0's multi_logloss: 0.432268
# [69]	valid_0's multi_logloss: 0.431392
# [70]	valid_0's multi_logloss: 0.431162
# [71]	valid_0's multi_logloss: 0.429932
# [72]	valid_0's multi_logloss: 0.428696
# [73]	valid_0's multi_logloss: 0.427667
# [74]	valid_0's multi_logloss: 0.426464
# [75]	valid_0's multi_logloss: 0.424476
# [76]	valid_0's multi_logloss: 0.424314
# [77]	valid_0's multi_logloss: 0.424994
# [78]	valid_0's multi_logloss: 0.425428
# [79]	valid_0's multi_logloss: 0.425861
# [80]	valid_0's multi_logloss: 0.427124
# [81]	valid_0's multi_logloss: 0.42659
# Early stopping, best iteration is:
# [76]	valid_0's multi_logloss: 0.424314
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# set parameters
params = {}
params['device'] = 'gpu'
params['gpu_id'] = 1
params['updater'] = 'grow_gpu_hist'

# %%
# define and fit
model = xgb.XGBClassifier(**params)
model.fit(X_train, y_train)

# result append to list
# pickle.dump(model, open('../model/xgb_pos_fs.sav', 'wb'))
t.append(round(model.score(X_test, y_test)*100, 2))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
tf.set_random_seed(42)

# make keras model

inputs = Input(shape=(X_train.shape[1],))

x = Dense(512, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(len(df['Subclass'].value_counts()), activation='softmax')(x)
model = Model(inputs=inputs, outputs=predictions)

# compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['accuracy']
)

# fit
epochs = 100
batch_size = 1000
es = EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(
    X_train,
    y_train_for_keras,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_test, y_test_for_keras),
    verbose=1,
    callbacks=[
        es,
#         lr_decay
    ]
)

# model.save('../model/Keras_pos_fs.h5')
t.append(round(model.evaluate(X_test, y_test_for_keras, verbose=0)[1]*100, 2))
# Out:
# Train on 1340 samples, validate on 336 samples
# Epoch 1/100
# 1340/1340 [==============================] - 3s 2ms/step - loss: 1.9195 - acc: 0.2261 - val_loss: 1.4578 - val_acc: 0.2173
# Epoch 2/100
# 1340/1340 [==============================] - 1s 799us/step - loss: 1.7867 - acc: 0.2746 - val_loss: 1.4025 - val_acc: 0.2619
# Epoch 3/100
# 1340/1340 [==============================] - 1s 768us/step - loss: 1.7028 - acc: 0.2649 - val_loss: 1.3275 - val_acc: 0.3185
# Epoch 4/100
# 1340/1340 [==============================] - 1s 773us/step - loss: 1.6304 - acc: 0.2963 - val_loss: 1.2811 - val_acc: 0.3393
# Epoch 5/100
# 1340/1340 [==============================] - 1s 770us/step - loss: 1.6103 - acc: 0.3127 - val_loss: 1.2672 - val_acc: 0.4286
# Epoch 6/100
# 1340/1340 [==============================] - 1s 769us/step - loss: 1.5778 - acc: 0.3239 - val_loss: 1.2709 - val_acc: 0.4821
# Epoch 7/100
# 1340/1340 [==============================] - 1s 789us/step - loss: 1.5257 - acc: 0.3179 - val_loss: 1.2821 - val_acc: 0.4405
# Epoch 8/100
# 1340/1340 [==============================] - 1s 762us/step - loss: 1.5341 - acc: 0.3410 - val_loss: 1.2858 - val_acc: 0.3929
# Epoch 9/100
# 1340/1340 [==============================] - 1s 782us/step - loss: 1.5051 - acc: 0.3485 - val_loss: 1.2865 - val_acc: 0.3869
# Epoch 10/100
# 1340/1340 [==============================] - 1s 785us/step - loss: 1.4505 - acc: 0.3567 - val_loss: 1.2721 - val_acc: 0.4018
# Epoch 11/100
# 1340/1340 [==============================] - 1s 777us/step - loss: 1.3548 - acc: 0.3754 - val_loss: 1.2514 - val_acc: 0.4881
# Epoch 12/100
# 1340/1340 [==============================] - 1s 753us/step - loss: 1.3645 - acc: 0.4157 - val_loss: 1.2314 - val_acc: 0.4702
# Epoch 13/100
# 1340/1340 [==============================] - 1s 767us/step - loss: 1.3056 - acc: 0.4336 - val_loss: 1.2101 - val_acc: 0.4732
# Epoch 14/100
# 1340/1340 [==============================] - 1s 759us/step - loss: 1.2907 - acc: 0.4485 - val_loss: 1.1923 - val_acc: 0.5000
# Epoch 15/100
# 1340/1340 [==============================] - 1s 775us/step - loss: 1.2444 - acc: 0.4590 - val_loss: 1.1714 - val_acc: 0.4970
# Epoch 16/100
# 1340/1340 [==============================] - 1s 757us/step - loss: 1.2504 - acc: 0.4545 - val_loss: 1.1488 - val_acc: 0.5119
# Epoch 17/100
# 1340/1340 [==============================] - 1s 785us/step - loss: 0.5808 - acc: 0.7701 - val_loss: 0.9835 - val_acc: 0.5952
# Epoch 38/100
# 1340/1340 [==============================] - 1s 779us/step - loss: 0.5002 - acc: 0.8045 - val_loss: 0.9214 - val_acc: 0.6280
# Epoch 39/100
# 1340/1340 [==============================] - 1s 815us/step - loss: 0.5169 - acc: 0.7925 - val_loss: 0.9268 - val_acc: 0.6399
# Epoch 40/100
# 1340/1340 [==============================] - 1s 772us/step - loss: 0.4834 - acc: 0.8149 - val_loss: 0.9829 - val_acc: 0.6310
# Epoch 41/100
# 1340/1340 [==============================] - 1s 782us/step - loss: 0.4668 - acc: 0.8142 - val_loss: 1.0485 - val_acc: 0.6131
# Epoch 42/100
# 1340/1340 [==============================] - 1s 774us/step - loss: 0.4693 - acc: 0.8276 - val_loss: 1.0814 - val_acc: 0.6042
# Epoch 43/100
# 1340/1340 [==============================] - 1s 772us/step - loss: 0.4483 - acc: 0.8381 - val_loss: 1.0646 - val_acc: 0.6071
# Epoch 44/100
# 1340/1340 [==============================] - 1s 754us/step - loss: 0.4048 - acc: 0.8604 - val_loss: 0.9956 - val_acc: 0.6250
# Epoch 45/100
# 1340/1340 [==============================] - 1s 764us/step - loss: 0.4042 - acc: 0.8507 - val_loss: 0.9865 - val_acc: 0.6250
# Epoch 46/100
# 1340/1340 [==============================] - 1s 772us/step - loss: 0.3568 - acc: 0.8590 - val_loss: 1.0084 - val_acc: 0.6280
# Epoch 47/100
# 1340/1340 [==============================] - 1s 766us/step - loss: 0.3803 - acc: 0.8634 - val_loss: 1.0634 - val_acc: 0.6190
# Epoch 48/100
# 1340/1340 [==============================] - 1s 774us/step - loss: 0.3454 - acc: 0.8761 - val_loss: 1.1481 - val_acc: 0.6399
# Epoch 49/100
# 1340/1340 [==============================] - 1s 759us/step - loss: 0.3658 - acc: 0.8746 - val_loss: 1.1003 - val_acc: 0.6369
# Epoch 50/100
# 1340/1340 [==============================] - 1s 773us/step - loss: 0.3375 - acc: 0.8836 - val_loss: 1.0042 - val_acc: 0.6726
# Epoch 51/100
# 1340/1340 [==============================] - 1s 773us/step - loss: 0.3361 - acc: 0.8888 - val_loss: 0.9846 - val_acc: 0.6667
# Epoch 52/100
# 1340/1340 [==============================] - 1s 788us/step - loss: 0.3015 - acc: 0.8970 - val_loss: 1.0384 - val_acc: 0.6518
# Epoch 53/100
# 1340/1340 [==============================] - 1s 788us/step - loss: 0.3037 - acc: 0.8955 - val_loss: 1.1503 - val_acc: 0.6399

# %%
f = []
f.append(t)

# %%
with open('../data/HCD35_neg.pickle', mode='rb') as fp:
    df_3 = pickle.load(fp)
    
df = pd.concat([
    df_3,
    pd.read_csv('../data/decomp_neg.csv').drop('Subclass', axis=1)
], axis=1)

# %%
# divide objective and target
objective = df.Subclass
le = preprocessing.LabelEncoder()
objective = le.fit_transform(objective)
features = df.drop('Subclass', axis=1)

# train test split
random_state=np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    objective,
    test_size=0.2
)

# transform  for keras's target label
y_train_for_keras = np_utils.to_categorical(y_train)
y_test_for_keras = np_utils.to_categorical(y_test)

# %%
# define and fit 
clf = rf()
clf = clf.fit(X_train, y_train)

# result append to list
t = []
t.append(round(clf.score(X_test, y_test)*100, 2))
# pickle.dump(clf, open('../model/rf_ng_fs.sav', 'wb'))

# %%
# define and fit
gbm = lgb.LGBMClassifier(
    objective='multiclass',
    device = 'gpu'
)

gbm.fit(
    X_train, 
    y_train,
    eval_set=[(X_test, y_test)],
    early_stopping_rounds=5
)

# pickle.dump(gbm, open('../model/lgbm_ng_fs.sav', 'wb'))
# result append to list
t.append(round(gbm.score(X_test, y_test)*100, 2))
# Out:
# [1]	valid_0's multi_logloss: 1.29219
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's multi_logloss: 1.21019
# [3]	valid_0's multi_logloss: 1.14622
# [4]	valid_0's multi_logloss: 1.08733
# [5]	valid_0's multi_logloss: 1.03251
# [6]	valid_0's multi_logloss: 0.992919
# [7]	valid_0's multi_logloss: 0.95358
# [8]	valid_0's multi_logloss: 0.920615
# [9]	valid_0's multi_logloss: 0.886328
# [10]	valid_0's multi_logloss: 0.861479
# [11]	valid_0's multi_logloss: 0.836112
# [12]	valid_0's multi_logloss: 0.81338
# [13]	valid_0's multi_logloss: 0.792016
# [14]	valid_0's multi_logloss: 0.768451
# [15]	valid_0's multi_logloss: 0.74962
# [16]	valid_0's multi_logloss: 0.732339
# [17]	valid_0's multi_logloss: 0.718509
# [18]	valid_0's multi_logloss: 0.70718
# [19]	valid_0's multi_logloss: 0.697032
# [20]	valid_0's multi_logloss: 0.68806
# [21]	valid_0's multi_logloss: 0.677009
# [22]	valid_0's multi_logloss: 0.664412
# [23]	valid_0's multi_logloss: 0.655272
# [24]	valid_0's multi_logloss: 0.648523
# [25]	valid_0's multi_logloss: 0.639871
# [26]	valid_0's multi_logloss: 0.632547
# [27]	valid_0's multi_logloss: 0.625757
# [28]	valid_0's multi_logloss: 0.618403
# [29]	valid_0's multi_logloss: 0.618315
# [30]	valid_0's multi_logloss: 0.611511
# [31]	valid_0's multi_logloss: 0.607857
# [32]	valid_0's multi_logloss: 0.60372
# [33]	valid_0's multi_logloss: 0.599505
# [34]	valid_0's multi_logloss: 0.598059
# [35]	valid_0's multi_logloss: 0.592939
# [36]	valid_0's multi_logloss: 0.593652
# [37]	valid_0's multi_logloss: 0.593259
# [38]	valid_0's multi_logloss: 0.591741
# [39]	valid_0's multi_logloss: 0.587395
# [40]	valid_0's multi_logloss: 0.589376
# [41]	valid_0's multi_logloss: 0.587309
# [42]	valid_0's multi_logloss: 0.586413
# [43]	valid_0's multi_logloss: 0.587042
# [44]	valid_0's multi_logloss: 0.58535
# [45]	valid_0's multi_logloss: 0.581537
# [46]	valid_0's multi_logloss: 0.578249
# [47]	valid_0's multi_logloss: 0.576504
# [48]	valid_0's multi_logloss: 0.574342
# [49]	valid_0's multi_logloss: 0.574417
# [50]	valid_0's multi_logloss: 0.574065
# [51]	valid_0's multi_logloss: 0.574835
# [52]	valid_0's multi_logloss: 0.579001
# [53]	valid_0's multi_logloss: 0.578991
# [54]	valid_0's multi_logloss: 0.582603
# [55]	valid_0's multi_logloss: 0.58238
# Early stopping, best iteration is:
# [50]	valid_0's multi_logloss: 0.574065
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# setting parameters
params = {}
params['device'] = 'gpu'
params['gpu_id'] = 1
params['updater'] = 'grow_gpu_hist'

# %%
# define and fit 
model = xgb.XGBClassifier(**params)
model.fit(X_train, y_train)

# result append to list
t.append(round(model.score(X_test, y_test)*100, 2))
# pickle.dump(model, open('../model/xgb_ng_fs.sav', 'wb'))
# Out:
# /home/yoshitaka-i/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
tf.set_random_seed(42)

# make keras model

inputs = Input(shape=(X_train.shape[1],))

x = Dense(512, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(len(df['Subclass'].value_counts()), activation='softmax')(x)
model = Model(inputs=inputs, outputs=predictions)

# compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['accuracy']
)

# fit
epochs = 100
batch_size = 1000
es = EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(
    X_train,
    y_train_for_keras,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_test, y_test_for_keras),
    verbose=1,
    callbacks=[
        es,
#         lr_decay
    ]
)

# model.save('../model/Keras_ng_fs.h5')
t.append(round(model.evaluate(X_test, y_test_for_keras, verbose=0)[1]*100, 2))
# Out:
# Train on 373 samples, validate on 94 samples
# Epoch 1/100
# 373/373 [==============================] - 2s 6ms/step - loss: 2.2399 - acc: 0.2011 - val_loss: 1.4254 - val_acc: 0.3617
# Epoch 2/100
# 373/373 [==============================] - 0s 293us/step - loss: 1.9099 - acc: 0.2547 - val_loss: 1.3959 - val_acc: 0.4149
# Epoch 3/100
# 373/373 [==============================] - 0s 299us/step - loss: 1.6998 - acc: 0.2842 - val_loss: 1.4462 - val_acc: 0.4255
# Epoch 4/100
# 373/373 [==============================] - 0s 318us/step - loss: 1.7601 - acc: 0.3298 - val_loss: 1.5122 - val_acc: 0.4574
# Epoch 5/100
# 373/373 [==============================] - 0s 294us/step - loss: 1.6800 - acc: 0.3566 - val_loss: 1.5430 - val_acc: 0.4681
# Epoch 6/100
# 373/373 [==============================] - 0s 279us/step - loss: 1.6782 - acc: 0.3780 - val_loss: 1.5367 - val_acc: 0.4681
# Epoch 7/100
# 373/373 [==============================] - 0s 262us/step - loss: 1.6358 - acc: 0.3378 - val_loss: 1.4952 - val_acc: 0.4681
# Epoch 8/100
# 373/373 [==============================] - 0s 267us/step - loss: 1.5384 - acc: 0.4075 - val_loss: 1.4389 - val_acc: 0.4894
# Epoch 9/100
# 373/373 [==============================] - 0s 316us/step - loss: 1.5445 - acc: 0.3914 - val_loss: 1.3893 - val_acc: 0.4894
# Epoch 10/100
# 373/373 [==============================] - 0s 260us/step - loss: 1.4810 - acc: 0.4263 - val_loss: 1.3415 - val_acc: 0.4894
# Epoch 11/100
# 373/373 [==============================] - 0s 292us/step - loss: 1.4802 - acc: 0.3673 - val_loss: 1.2954 - val_acc: 0.4894
